# %%
from datetime import datetime

from config import Config
from extractors import CafeFExtractorETL
from utils import setup_logger

# %%
logger = setup_logger(Config.DEFAULT_LOGGER_NAME)

extractor = CafeFExtractorETL()

# %%
def run(date_ref: datetime, is_raw: bool = True) -> None:
    try:
        if date_ref.weekday() in (5, 6):
            logger.warning(f"📅 Ngày {date_ref.strftime('%d/%m/%Y')} là cuối tuần. Bỏ qua.")
            return None

        df = extractor.run(date_ref, is_raw=is_raw)
        if df is not None:
            return df
    except Exception as e:
        logger.error(f"🚨 Sự cố nghiêm trọng sập hệ thống toàn cục: {e}", exc_info=True)

# %%
def main():
    logger.info(f"[bold cyan]🚀 === KHỞI ĐỘNG PIPELINE ===[/bold cyan]")

    is_raw = True
    # start_date = "2026-04-02"
    # end_date = "2026-05-29"

    # # Generate business days between two dates
    # bdays = pd.bdate_range(start=start_date, end=end_date, holidays=Config.VN_HOLIDAY_DATES, freq="C")

    # # Convert to a list of strings or datetime objects
    # bdays = list(bdays.to_pydatetime())

    # for d in bdays:
    #     run(d, is_raw)

    return run(datetime(2026, 5, 29), is_raw)

# %%
df = main()
# Out:
# [06/08/26 02:00:46] INFO     🚀 === KHỞI ĐỘNG PIPELINE ===
#                     INFO     🚀 Khởi chạy Pipeline CafeF [RAW] ngày: 2026-05-29
#                     INFO     ⏳ [Downloader] Chờ 2.55s để giãn cách tần suất request...
# [06/08/26 02:00:49] INFO     📥 [CafeF] Đang tải file lịch sử từ URL:
#                              https://cafef1.mediacdn.vn/data/ami_data/20260529/CafeF.SolieuGD.Raw.Upto29052026.zip
# [06/08/26 02:01:00] INFO     📂 Đang trích xuất & xử lý stream sàn: CafeF.RAW_HSX.Upto29.05.2026.csv
# [06/08/26 02:01:01] INFO     📂 Đang trích xuất & xử lý stream sàn: CafeF.RAW_HNX.Upto29.05.2026.csv
#                     INFO     📂 Đang trích xuất & xử lý stream sàn: CafeF.RAW_UPCOM.Upto29.05.2026.csv
# [06/08/26 02:01:02] INFO     🧱 Đang gộp các phân đoạn dữ liệu lịch sử và tối ưu RAM...
# [06/08/26 02:01:03] INFO     ✅ Tải và làm sạch dữ liệu thành công! Kích thước: (3251905, 8)
#                     INFO     💾 Đang ghi dữ liệu nén Parquet: historical_raw_upto_20260529.parquet
#                     INFO     🎉 File lưu trữ thành công tại: tmp/historical/historical_raw_upto_20260529.parquet
#                     INFO     ⚡ [Snapshot] Đang trích xuất trạng thái thị trường EOD...
#                     INFO     💾 [Snapshot Thành Công] Đã cập nhật tổng cộng 3618 mã tại: tmp/latest_state.json
#                     INFO     🏁 Pipeline hoàn thành xuất sắc! Tổng số dòng xử lý: 3,251,905
#                     INFO     🔌 [Downloader] Đã đóng tài nguyên kết nối mạng an toàn.
